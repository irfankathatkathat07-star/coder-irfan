# %% [markdown]
# <a href="https://colab.research.google.com/github/irfankathatkathat07-star/coder-irfan/blob/main/regex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create a small atm machine using functions
# functions== deposit, withdraw, display_balance
total_amount = 100
def deposit():
    global total_amount
    deposit = int(input("enter ur deposit amount"))
    total_amount+=deposit
    print("new balace=", total_amount)
    deposit()
    print(total_amount)

# %%
list1 = ["india", "china", "usa"]
list1.pop()
print(list1)
list1.pop()
print(list1)
# Out:
# ['india', 'china']
# ['india']

# %%
list1 = ["india", "china", "usa"]
print(list1[start:end:step])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1882/1035940125.py in <cell line: 0>()
#       1 list1 = ["india", "china", "usa"]
# ----> 2 print(list1[start:end:step])
#
# NameError: name 'start' is not defined

# %%
list1 = ["india", "china", "usa"]
print(list1[1:3:2])

# %%
list1 = ["india", "china", "usa"]
list1.append("england")
print(list1)

# %%
list1 = ["india", "china", "usa"]
list1.pop()
print(list1)
list1.pop()
print(list1)

# %%
list1 = ["india", "china", "usa"]
list1.remove("china")
print(list1)

# %%
list1 = ["india", "china", "usa","england", "pakistan"]
for i in list1:
    print(i, end = " ")

# %%
list1 = ["india", "china", "usa","england", "pakistan"]

# %%
#tuple
mytuple = (1,2,3,4,5,"hello world",True,True)
print(mytuple)
print(type(mytuple))

# %%
#tuple
mytuple = (1,2,3,4,5,"hello world",True,True)
mylist = list(mytuple)
print(type(mytuple))
mylist.pop()
mytuple = tuple(mylist)
print(mytuple)

# %%
#sets
myset = {1,2,3,4,5}
print(myset)
print(type(myset))

# %%
#sets
myset = {1,"hello",2,"hii",3,4,"india",5,True,True}
print(myset)
print(type(myset))

# %%
#sets
myset = {1,1,1,1}
print(myset)
print(type(myset))

# %%
#sets
myset = {1,2,3,4,5}
print(0)
print(type(myset))

# %%
#sets
myset = {1,2,3,4,5}
myset.add(2.5)
print(myset)

# %%
#sets
myset = {1,2,3,4,5}
myset.pop()
print(myset)

# %%
#sets
myset = {1,2,3,4,5}
myset.remove(3)
print(myset)

# %%
#dictionary

mydict = {
    "name":"lucky",
    "age":19
}
print(mydict["name"])

# %%
#dictionary

mydict = {
    "car":"scorpio",
    "year":2028,
    "colouur":"white",
    "fuel":"petrol"
}
print(mydict["car"])

# %%
string = "hello how are you"
for X in string:
    if X == "e" or X == "a' or X == "i" or X == "u" or X == "o":
    count_vowel+=1
    else:
    count_consonent+=1
    print(count_vowel)
    print(count_consonent)

# %%
string = "hello how are you"
for x in string:
    if x == "e" or x == "a' or x == "i" or x == "u" or x == "o":
    count_vowel = 0
    count_consonent = 0
    else:
   for x in string:
   for x in
    print(count_vowel)
    print(count_consonent)

# %%
def add(a,b): # parameters
    print(a+b)

    add(10,20) # arguments
    add(30,50)
    add(70,80) #positional arguments

# %%
def greetings(name,age):
    print("hello",name,"ur age is=",age)
    greetings(age = 42,name = "lucky") #keyword arguments

# %%
def func1(): #outer function
    def func2(): #inner function
        print("hello world")
        func2()

        func1()

# %%
def arg():

# %%
# create a small atm machine using functions
# functions== deposit, withdraw, display_balance
total_amount = 100
def deposit():
    global total_amount
    deposit = int(input("enter ur deposit amount"))
    total_amount+=deposit
    print("new balace=", total_amount)
    deposit()
    print(total_amount)

# %%
class car:
  bmw = car()
  tyre = 4
  seats = 5

class bike:
  ktm = bike()
  tyre = 2
  seats = 1
  print("tyre in car=",bmw,tyre,"tyre in bike=",ktm,tyre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1882/160192809.py in <cell line: 0>()
#       4   seats = 5
#       5
# ----> 6 class bike:
#       7   ktm = bike()
#       8   tyre = 2
#
# /tmp/ipykernel_1882/160192809.py in bike()
#       5
#       6 class bike:
# ----> 7   ktm = bike()
#       8   tyre = 2
#       9   seats = 1
#
# NameError: name 'bike' is not defined

# %%
#methods
class car:
  def move(self): #method(if inside a clss)
    print("this car is moving")

    car1 = car
    car1.move()

# %%
class student:
  school_name = "vgu"
def __init__(self,name,age):
self.name = name
self.age = age

o1 = student("rohit",21)
o1 = student("lucky",22)
o1 = student("ishu",23)
print(o1.name,o1.age,o1.school_name)
